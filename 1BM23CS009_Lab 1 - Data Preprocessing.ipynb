# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler

df_diabetes=pd.read_csv("/Dataset of Diabetes .csv")
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   object
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  CLASS      1000 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 109.5+ KB
# None
#                 ID     No_Pation          AGE         Urea           Cr  \
# count  1000.000000  1.000000e+03  1000.000000  1000.000000  1000.000000
# ...

# %%
df_diabetes.info()
df_diabetes.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   object
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  CLASS      1000 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 109.5+ KB
# Index(['ID', 'No_Pation', 'Gender', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG',
#        'HDL', 'LDL', 'VLDL', 'BMI', 'CLASS'],
#       dtype='object')

# %%
#data cleaning

# %%
numeric_cols = [
    'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol',
    'TG', 'HDL', 'LDL', 'VLDL', 'BMI'
]

# %%
df_diabetes[numeric_cols] = df_diabetes[numeric_cols].replace(0, np.nan)
df_diabetes[numeric_cols] = df_diabetes[numeric_cols].fillna(
    df_diabetes[numeric_cols].mean()
)

# %%
le = LabelEncoder()
df_diabetes['Gender'] = le.fit_transform(df_diabetes['Gender'])

# %%
Q1 = df_diabetes[numeric_cols].quantile(0.25)
Q3 = df_diabetes[numeric_cols].quantile(0.75)
IQR = Q3 - Q1

df_diabetes = df_diabetes[
    ~((df_diabetes[numeric_cols] < (Q1 - 1.5 * IQR)) |
      (df_diabetes[numeric_cols] > (Q3 + 1.5 * IQR))).any(axis=1)
]

# %%
scaler = StandardScaler()
df_diabetes[numeric_cols] = scaler.fit_transform(df_diabetes[numeric_cols])

# %%
df_diabetes.head()
df_diabetes.describe()
# Out:
#                ID     No_Pation      Gender           AGE          Urea  \
# count  679.000000  6.790000e+02  679.000000  6.790000e+02  6.790000e+02
# mean   334.092784  6.936560e+04    0.533137 -1.255746e-16  1.098777e-16
# std    237.009506  3.514754e+05    0.502214  1.000737e+00  1.000737e+00
# min      2.000000  1.230000e+02    0.000000 -2.826163e+00 -2.362998e+00
# 25%    117.000000  2.405500e+04    0.000000 -5.020955e-01 -7.162559e-01
# 50%    300.000000  3.436500e+04    1.000000  3.422780e-02 -9.872771e-02
# 75%    519.500000  3.491350e+04    1.000000  7.493255e-01  5.874147e-01
# max    800.000000  7.565435e+06    2.000000  2.715844e+00  2.851685e+00
#
#                  Cr         HbA1c          Chol            TG           HDL  \
# count  6.790000e+02  6.790000e+02  6.790000e+02  6.790000e+02  6.790000e+02
# mean   1.046455e-17  1.255746e-16  1.255746e-16 -1.046455e-17  3.348655e-16
# std    1.000737e+00  1.000737e+00  1.000737e+00  1.000737e+00  1.000737e+00
# ...
